# %% [markdown]
# <font size="5"><b><center>INSIGHTS FROM TEXTUAL DATA</center></b></font>
# <font size="2"><b><center>CLASSWORK-2</center></b></font>

# %% [markdown]
# <font size="3"><b>UN GENERAL ASSEMBLY SPEECHES DATASET OVERVIEW</b></font>
#
# **Size:** Medium-sized dataset with 7 columns and 7507 long speeches.
#
# **Columns:**
# 1. `Session`: Indicates the session during which the speech was given.
# 2. `Year`: Represents the year in which the speech took place.
# 3. `Country`: Code or identifier for the country giving the speech.
# 4. `Country_name`: Full name of the country giving the speech.
# 5. `Speaker`: Identifies the speaker delivering the speech.
# 6. `Position`: Specifies the position or role of the speaker.
# 7. `Text`: Contains the actual text of the speech.
#
# This dataset captures a comprehensive set of information regarding speeches made at the UN General Assembly from 1970 to 2016. The columns provide details about the session, year, country, speaker, position, and the content of each speech. Analyzing this dataset could offer insights into trends in international relations, diplomatic discourse, or changes in the global political landscape over the specified period. Depending on your research objectives, you can explore patterns, sentiments, or topics discussed in the speeches using various data analysis and visualization techniques.chniques.
# ext
# ext

# %% [markdown]
# <font size="3"><b>LOADING DATA SET</b></font>

# %%
# Loading data set using pandas.
# !pip install pandas

import pandas as pd

file= "C:/Users/aleky/Desktop/TextBasedAnalysis/un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df.head(20)
# Out:
# Requirement already satisfied: pandas in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# C:\Users\aleky\AppData\Local\Temp\ipykernel_6580\1963898012.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %% [markdown]
# <font size="3"><b>PRINTING A DATA FRAME</b></font>

# %%
#Display the few rows of the DataFrame
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            Mr. NAS
# 1          25  1970     ARG     Argentina                 Mr. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        Mr. McMAHON
# 3          25  1970     AUT       Austria                 Mr. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         Mr. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7503       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7504       70  2015     ZAF  South Africa                         Jacob Zuma
# 7505       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7506       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text
# 0           NaN  33: May I first convey to our President the co...
# 1           NaN  177.\t : It is a fortunate coincidence that pr...
# 2           NaN  100.\t  It is a pleasure for me to extend to y...
# 3           NaN  155.\t  May I begin by expressing to Ambassado...
# 4           NaN  176. No doubt each of us, before coming up to ...
# ...         ...                                                ...
# 7502  President  On behalf of the people and the Government of ...
# 7503  President  \nSeventy years have passed since the establis...
# 7504  President  I should like to congratulate the President an...
# 7505  President  I would like to begin by thanking the Secretar...
# 7506  President  Allow me at the outset to extend to Mr. Mogens...
#
# [7507 rows x 7 columns]

# %% [markdown]
# <font size="3"><b>ACCESSING A DATA FRAME</b></font>

# %%
# df.columns return columns of data frame
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %% [markdown]
# <font size="3"><b>PRINTING DATA TYPES OF COLUMNS</b></font>

# %%
# df.dtypes returns data types of the data frame
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# <font size="3"><b>PRINTING INFORMATION OF DATA</b></font>

# %%
#df.info returns concise summary of a DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %% [markdown]
# <font size="3"><b>PRINTING STATISTICAL INFORMATION OF DATA</b></font>

# %%
#The df.describe() method in pandas is used to generate descriptive statistics of the central tendency, dispersion, and shape of a DataFrame's distribution, excluding NaN values
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# <font size="3"><b>ADDING A NEW COLUMN TO THE DATAFRAME</b></font>

# %%
#Let’s add a new column with the length of the “text” column
#df['text']: Selects the 'text' column from the DataFrame.
#.str.len(): Applies the len() function to each element in the 'text' column, returning the length of each string.
#df['length'] = ...: Creates a new column named 'length' in the DataFrame and assigns the calculated lengths to this column

df['length'] = df['text'].str.len()
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %% [markdown]
# <font size="3"><b>PRINTING INFORMATION OF DATAFRAMEE</b></font>

# %%
#The df.describe(include='O') output will show statistics for each object (string) column in your DataFrame.
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# <font size="3"><b>FINDING A MISSING VALUES OF DATAFRAMEE</b></font>

# %%
#df.isna().sum() output will show the count of missing values for each column in your DataFrame.
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %% [markdown]
# <font size="3"><b>REPLACING MISSING DATA</b></font>

# %%
#df['speaker'].fillna('unknown', inplace=True): Fills missing values in the 'speaker' column with the value 'unknown'.
#df['position'].fillna('unknown', inplace=True): Fills missing values in the 'position' column with the value 'unknown'.
#df.isna().sum(): Checks and displays the sum of missing values for each column in the DataFrame after the fillna operations.

df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# C:\Users\aleky\AppData\Local\Temp\ipykernel_6580\454902244.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['speaker'].fillna('unknown', inplace=True)
# C:\Users\aleky\AppData\Local\Temp\ipykernel_6580\454902244.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['position'].fillna('unknown', inplace=True)
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# <font size="3"><b>CONVERTING UPPERCASE AND LOWERCASE</b></font>

# %%
#df['speaker'] = df['speaker'].str.upper(): Converts the values in the 'speaker' column to uppercase.
#df['position'] = df['position'].str.upper(): Converts the values in the 'position' column to uppercase.
#df['text'] = df['text'].str.upper(): Converts the values in the 'text' column to uppercase.


df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()
print (df)
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length
# 0       UNKNOWN  33: MAY I FIRST CONVEY TO OUR PRESIDENT THE CO...   51419
# 1       UNKNOWN  177.\t : IT IS A FORTUNATE COINCIDENCE THAT PR...   29286
# 2       UNKNOWN  100.\t  IT IS A PLEASURE FOR ME TO EXTEND TO Y...   31839
# 3       UNKNOWN  155.\t  MAY I BEGIN BY EXPRESSING TO AMBASSADO...   26616
# 4       UNKNOWN  176. NO DOUBT EACH OF US, BEFORE COMING UP TO ...   25911
# ...         ...                                                ...     ...
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
# [7507 rows x 8 columns]

# %% [markdown]
# <font size="3"><b>PRINTING A DATA WITH SPEAKER NAMED BUSH</b></font>

# %%
#df['speaker'].str.contains('BUSH'): Returns a boolean Series indicating whether each element in the 'speaker' column contains the substring 'BUSH'.
#df[df['speaker'].str.contains('BUSH')]: Uses boolean indexing to select only the rows where the condition is True.

df[df['speaker'].str.contains('BUSH')]
print (df)
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length
# 0       UNKNOWN  33: MAY I FIRST CONVEY TO OUR PRESIDENT THE CO...   51419
# 1       UNKNOWN  177.\t : IT IS A FORTUNATE COINCIDENCE THAT PR...   29286
# 2       UNKNOWN  100.\t  IT IS A PLEASURE FOR ME TO EXTEND TO Y...   31839
# 3       UNKNOWN  155.\t  MAY I BEGIN BY EXPRESSING TO AMBASSADO...   26616
# 4       UNKNOWN  176. NO DOUBT EACH OF US, BEFORE COMING UP TO ...   25911
# ...         ...                                                ...     ...
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
# [7507 rows x 8 columns]

# %% [markdown]
# <font size="3"><b>PLOTTING CHARTS</b></font>

# %%
#df['length'].plot(): This creates a line plot for the 'length' column. The x-axis will likely represent the index of the DataFrame, and the y-axis will represent the values in the 'length' column.
#df['length'].plot(kind='box', vert=False): This creates a horizontal box plot for the 'length' column. Box plots provide a visual summary of the distribution of data, including the median, quartiles, and potential outliers.

# !pip install matplotlib

import matplotlib.pyplot as plt
df['length'].plot()
plt.xlabel('Range of length') 
plt.ylabel('Length')
plt.title('Line Plot of Length Column')
# Out:
# Requirement already satisfied: matplotlib in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Text(0.5, 1.0, 'Line Plot of Length Column')

# %% [markdown]
# <font size="3"><b>BOX PLOT</b></font>

# %%
df['length'].plot(kind='box', vert=False)
plt.xlabel('Range of length')
plt.ylabel('Length') 
plt.title('Box Plot of Length Column')
# Out:
# Text(0.5, 1.0, 'Box Plot of Length Column')

# %% [markdown]
# <font size="3"><b>HISTOGRAM</b></font>

# %%
#df['length'].plot(kind='hist', bins=30): This creates a histogram for the 'length' column with 30 bins. The x-axis represents the range of 'length' values, and the y-axis represents the frequency or count of values within each bin.

df['length'].plot(kind='hist', bins=30)
plt.xlabel('Range of length')  
plt.ylabel('Length')  
plt.title('Histogram of Length Column')
# Out:
# Text(0.5, 1.0, 'Histogram of Length Column')

# %% [markdown]
# <font size="3"><b>BOX PLOT</b></font>

# %%
import seaborn as sns 

where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box',)
g.fig.set_size_inches(10, 8) ###
plt.title('Box Plot of Length Column across Countries')
# Out:
# C:\Users\aleky\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Text(0.5, 1.0, 'Box Plot of Length Column across Countries')

# %% [markdown]
# <font size="3"><b>REGEX TO PULL OUT WORDS</b></font>

# %%
# !pip install regex
import regex as re
import pandas as pd

def tokenize(text):
    return re.findall(r'[\w-]*[a-zA-Z][\w-]*', text)

file_path = "C:/Users/aleky/Desktop/TextBasedAnalysis/un-general-debates-blueprint.csv"

df = pd.read_csv(file_path)

df['tokenized_text'] = df['text'].apply(lambda x: tokenize(str(x)))

# Display the DataFrame with the tokenized text
print(df[['text', 'tokenized_text']].head())
# Out:
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: regex in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (2023.12.25)
#                                                 text  \
# 0  33: May I first convey to our President the co...
# 1  177.\t : It is a fortunate coincidence that pr...
# 2  100.\t  It is a pleasure for me to extend to y...
# 3  155.\t  May I begin by expressing to Ambassado...
# 4  176. No doubt each of us, before coming up to ...
#
#                                       tokenized_text
# 0  [May, I, first, convey, to, our, President, th...
# 1  [It, is, a, fortunate, coincidence, that, prec...
# 2  [It, is, a, pleasure, for, me, to, extend, to,...
# 3  [May, I, begin, by, expressing, to, Ambassador...
# 4  [No, doubt, each, of, us, before, coming, up, ...

# %% [markdown]
# <font size="3"><b>FUNCTION TO TOKENIZE</b></font>

# %%
import regex as re
import pandas as pd

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# file path
file_path = "C:/Users/aleky/Desktop/TextBasedAnalysis/un-general-debates-blueprint.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)
df['tokenized_text'] = df['text'].apply(lambda x: tokenize(str(x)))

# Display the DataFrame with the tokenized text
print(df[['text', 'tokenized_text']].head())
# Out:
#                                                 text  \
# 0  33: May I first convey to our President the co...
# 1  177.\t : It is a fortunate coincidence that pr...
# 2  100.\t  It is a pleasure for me to extend to y...
# 3  155.\t  May I begin by expressing to Ambassado...
# 4  176. No doubt each of us, before coming up to ...
#
#                                       tokenized_text
# 0  [May, I, first, convey, to, our, President, th...
# 1  [It, is, a, fortunate, coincidence, that, prec...
# 2  [It, is, a, pleasure, for, me, to, extend, to,...
# 3  [May, I, begin, by, expressing, to, Ambassador...
# 4  [No, doubt, each, of, us, before, coming, up, ...

# %% [markdown]
# <font size="3"><b>STOPWORDS FROM DATASET</b></font>

# %%
# !pip install nltk

import nltk
import pandas as pd

nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)

# Specify the file path
file_path = "C:/Users/aleky/Desktop/TextBasedAnalysis/un-general-debates-blueprint.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
print(df.head())
# Out:
# Requirement already satisfied: nltk in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aleky\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'is', 'below', 'if', 'between', 'does', 'ourselves', 'its', 'doing', 'but', 'about', 'here', "don't", "shouldn't", 'mightn', 'did', 'out', 'aren', 'or', 'both', 'very', 'was', 'by', 'in', 'just', 'while', "hadn't", 'we', 'mustn', 'are', 's', 'other', 'hasn', 'those', 'up', 've', "you'd", 'doesn', 'been', 'll', 'o', 'haven', 'having', 'at', 'during', "you'll", 'which', "haven't", 'to', 'off', 'than', 'yourselves', 'isn', 'hadn', "that'll", 'same', 'once', 'these', 'when', 'ain', 'weren', "aren't", "isn't", 'y', 'yourself', 'after', 'and', 'ours', 'further', 'now', 'no', "you're", 'until', 'themselves', 'with', 'most', 'have', 'against', 'there', 'being', 'only', "hasn't", 'shan', 'our', 'were', 'your', 'few', 'how', 'own', "wasn't", 'as', 'some', 'myself', 'don', 're', 'ma', 'shouldn', 'of', 'their', 'herself', 'yours', 'what', 'any', 'them', 'all', "should've", 'his', "she's", 'd', 'wouldn', 'him', 'nor', 't', 'above', "needn't", "mustn't", 'into', 'her', 'it', "you've", 'hers', "mightn't", 'won', 'the', 'more', "couldn't", 'wasn', "doesn't", 'whom', 'then', 'will', 'down', 'needn', "weren't", 'an', 'himself', 'that', 'should', 'under', 'he', 'on', 'she', 'too', 'couldn', 'this', "didn't", 'me', 'do', 'who', 'not', "shan't", 'i', 'over', 'can', 'am', 'for', "won't", 'theirs', 'where', 'each', 'itself', 'before', 'had', 'again', 'through', 'why', 'they', "it's", 'be', "wouldn't", 'm', 'because', 'such', 'a', 'so', 'from', 'has', 'my', 'didn', 'you'}
#    session  year country country_name             speaker position  \
# 0       25  1970     ALB      Albania             Mr. NAS      NaN
# 1       25  1970     ARG    Argentina  Mr. DE PABLO PARDO      NaN
# 2       25  1970     AUS    Australia         Mr. McMAHON      NaN
# 3       25  1970     AUT      Austria  Mr. KIRCHSCHLAEGER      NaN
# 4       25  1970     BEL      Belgium          Mr. HARMEL      NaN
#
#                                                 text
# 0  33: May I first convey to our President the co...
# 1  177.\t : It is a fortunate coincidence that pr...
# 2  100.\t  It is a pleasure for me to extend to y...
# 3  155.\t  May I begin by expressing to Ambassado...
# 4  176. No doubt each of us, before coming up to ...

# %% [markdown]
# <font size="3"><b>REMOVING STOPWORDS</b></font>

# %%
#function to remove stop words
import pandas as pd
import nltk

# Download English stopwords
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))

# Define the remove_stop function
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# Read the CSV file into a DataFrame
file_path = "C:/Users/aleky/Desktop/TextBasedAnalysis/un-general-debates-blueprint.csv"
df = pd.read_csv(file_path)
df['cleantokens'] = df['text'].apply(lambda x: remove_stop(str(x).split()))

# Display the DataFrame with the cleaned tokens
print(df[['text', 'cleantokens']].tail())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aleky\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                    text  \
# 7502  On behalf of the people and the Government of ...
# 7503  \nSeventy years have passed since the establis...
# 7504  I should like to congratulate the President an...
# 7505  I would like to begin by thanking the Secretar...
# 7506  Allow me at the outset to extend to Mr. Mogens...
#
#                                             cleantokens
# 7502  [behalf, people, Government, Yemen,, would, li...
# 7503  [Seventy, years, passed, since, establishment,...
# 7504  [like, congratulate, President, country,, Denm...
# 7505  [would, like, begin, thanking, Secretary-Gener...
# 7506  [Allow, outset, extend, Mr., Mogens, Lykketoft...

# %% [markdown]
# <font size="3"><b>CREATING THE PIPELINE</b></font>

# %%
import pandas as pd
import nltk

# Download English stopwords
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))

# Define the tokenize function (replace with your actual tokenize implementation)
def tokenize(text):
    return re.findall(r'\b\w+\b', text)

# Define the remove_stop function
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# Define the text preparation pipeline
pipeline = [str.lower, tokenize, remove_stop]

# Define the prepare function
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

file_path = "C:/Users/aleky/Desktop/TextBasedAnalysis/un-general-debates-blueprint.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['processed_text'] = df['text'].apply(lambda x: prepare(str(x), pipeline))

# Display the DataFrame with the processed text
print(df[['text', 'processed_text']].tail())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aleky\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                    text  \
# 7502  On behalf of the people and the Government of ...
# 7503  \nSeventy years have passed since the establis...
# 7504  I should like to congratulate the President an...
# 7505  I would like to begin by thanking the Secretar...
# 7506  Allow me at the outset to extend to Mr. Mogens...
#
#                                          processed_text
# 7502  [behalf, people, government, yemen, would, lik...
# 7503  [seventy, years, passed, since, establishment,...
# 7504  [like, congratulate, president, country, denma...
# 7505  [would, like, begin, thanking, secretary, gene...
# 7506  [allow, outset, extend, mr, mogens, lykketoft,...

# %% [markdown]
# <font size="3"><b>RUN THE PIPELINE</b></font>

# %%
import pandas as pd
import regex as re

# Define the pipeline
pipeline = [str.lower, tokenize, remove_stop]

# Define the tokenize function
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# Define the remove_stop function
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# Define the prepare function
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# Specify the file path
file_path = "C:/Users/aleky/Desktop/TextBasedAnalysis/un-general-debates-blueprint.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['tokens'] = df['text'].apply(lambda x: prepare(str(x), pipeline=pipeline))

# Display the DataFrame with the processed tokens
print(df[['text', 'tokens']].head())
# Out:
#                                                 text  \
# 0  33: May I first convey to our President the co...
# 1  177.\t : It is a fortunate coincidence that pr...
# 2  100.\t  It is a pleasure for me to extend to y...
# 3  155.\t  May I begin by expressing to Ambassado...
# 4  176. No doubt each of us, before coming up to ...
#
#                                               tokens
# 0  [33, may, first, convey, president, congratula...
# 1  [177, fortunate, coincidence, precisely, time,...
# 2  [100, pleasure, extend, mr, president, warmest...
# 3  [155, may, begin, expressing, ambassador, hamb...
# 4  [176, doubt, us, coming, rostrum, wonders, use...

# %% [markdown]
# <font size="3"><b>COUNTING THE TOKENS</b></font>

# %%
#count the tokens
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7503       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7504       70  2015     ZAF  South Africa                         Jacob Zuma
# 7505       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7506       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text  \
# 7502  President  On behalf of the people and the Government of ...
# 7503  President  \nSeventy years have passed since the establis...
# 7504  President  I should like to congratulate the President an...
# 7505  President  I would like to begin by thanking the Secretar...
# 7506  President  Allow me at the outset to extend to Mr. Mogens...
#
#                                                  tokens  num_tokens
# 7502  [behalf, people, government, yemen, would, lik...         942
# 7503  [seventy, years, passed, since, establishment,...        2195
# 7504  [like, congratulate, president, country, denma...        1202
# 7505  [would, like, begin, thanking, secretary, gene...        1264
# 7506  [allow, outset, extend, mr, mogens, lykketoft,...         932

# %% [markdown]
# <font size="3"><b>WORD FREQUENCY ANALYSIS</b></font>

# %%
#Word frequency Analysis

from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# <font size="3"><b>ADDING DATA TO COUNT</b></font>

# %%
#Adding new data to the current count

more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# <font size="3"><b> LETS COUNT</b></font>

# %%
#Let’s count

counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 124783), ('united', 120950), ('international', 117238), ('world', 91134), ('countries', 85806)]

# %% [markdown]
# <font size="3"><b>FREQUENCY OF DATAFRAME</b></font>

# %%
#Now, we put the word frequency in it’s own dataframe for analysis

freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'
print(freq_df)
# Out:
#             freq
# token
# 33           886
# may        14998
# first      19081
# convey      1607
# president  18838
# ...          ...
# judas          1
# 524            1
# ghettoize      1
# unworried      1
# officiate      1
#
# [54835 rows x 1 columns]

# %% [markdown]
# <font size="3"><b>SORT AND DISPLAY</b></font>

# %%
#Lets sort and display

freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                  freq
# token
# nations        124783
# united         120950
# international  117238
# world           91134
# countries       85806
# peace           77845
# development     63063
# states          59982
# people          59578
# security        58622

# %% [markdown]
# <font size="3"><b>FINDING INFORMATION OF FREQUENCY</b></font>

# %%
freq_df.describe()
# Out:
#                 freq
# count   54835.000000
# mean      209.612456
# std      1754.219737
# min         1.000000
# 25%         1.000000
# 50%         4.000000
# 75%        27.000000
# max    124783.000000

# %% [markdown]
# <font size="3"><b>BAR CHART</b></font>

# %%
#Bar chart 

ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8),)
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# <font size="3"><b>WORD CLOUD</b></font>

# %%
#Word cloud
# !pip install wordcloud

from wordcloud import WordCloud
from matplotlib import pyplot as plt

text = df.query("year==2015 and country=='USA'")['text'].values[0]

plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: wordcloud in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (1.26.3)
# Requirement already satisfied: pillow in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\aleky\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# <font size="3"><b>ONE MORE EXAMPLE</b></font>

# %%
# Initialize a WordCloud object with specified parameters
wc = WordCloud(background_color='black', width = 300, height=300, max_words=100, margin=2)
# Fit the word frequencies from freq_df DataFrame into the WordCloud object
wc.fit_words(freq_df['freq'].to_dict() )
# Create a new figure with specified size and facecolor
plt.figure(figsize = (14, 8), facecolor = None)
# Display the word cloud
plt.imshow(wc)
# Remove the axis (x and y) from the plot for better visualization
plt.axis("off")
# Adjust the layout of the plot to ensure the word cloud fits well within the figure
plt.tight_layout(pad = 0)
# Show the plot
plt.show()
